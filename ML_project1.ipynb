# %%
# !git remote add origin git@github.com:avintha97/Machine_Learning_projects.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# #loading the data set using pandas Dataframe
# sonar_data = pd.read_csv('/content/sonarData.csv',header=None);
# sonar_data.head()

# %%
sonar_data = pd.read_csv('/content/sonarData.csv',header=None); sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data[60].value_counts()
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
#seperating data and labels
X=sonar_data.drop(columns=60,axis=1)
Y =sonar_data[60]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=1)

# %%
model=LogisticRegression()

# %%
y_train.shape
# Out:
# (21, 60)

# %%
model.fit(x_train,y_train)

# %%
x_train_prediction=model.predict(x_test)
data_accuracy = accuracy_score(x_train_prediction,y_test)

# %%
print("accuracy of the data model : ", data_accuracy)
# Out:
# accuracy of the data model :  0.7619047619047619

# %%
x_train_prediction_train=model.predict(x_train)
data_accuracy_train = accuracy_score(x_train_prediction_train,y_train)
print("accuracy of the data model : ", data_accuracy_train)
# Out:
# accuracy of the data model :  0.8342245989304813
